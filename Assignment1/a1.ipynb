# %%
# Task 1
def is_float(inStr): 
    """
    Checks if the given string inStr is a float (saved in string format) or not

    Input: A string
    Output: True if it is a float (saved in string format), False otherwise
    """
    test_float = inStr.split('.')
    if len(test_float)==2 and test_float[0].isnumeric() and test_float[1].isnumeric():
        return True
    return False

def read_data(filename):
    """
    Input: The name of the data file (filename)
    Output: A table with all the rows of data in the given file. 

    For example: 
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> laptops_data[:2] # The first two rows of the table
    [[1, 'Apple', 'MacBook Pro', 'Ultrabook', 13.3, 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', 2175.25], [2, 'Apple', 'Macbook Air', 'Ultrabook', 13.3, '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', 1459.61]]
    """
    file = open(filename, 'r')
    file.readline()
    table = []
    for i in file:
        line = i.strip().split(",")
        for j in range(len(line)):
            if line[j].isnumeric():
                line[j] = int(line[j])
            elif is_float(line[j]):
                line[j] = float(line[j])
            elif line[j].isalpha():
                line[j] = str(line[j])
        table.append(line)
    file.close()
    return table

lst = read_data('laptop_dataset.txt')
lst[:2]
# Out:
# [[1,
#   'Apple',
#   'MacBook Pro',
#   'Ultrabook',
#   13.3,
#   'IPS Panel Retina Display 2560x1600',
#   'Intel Core i5 2.3GHz',
#   '8GB',
#   '128GB SSD',
#   'Intel Iris Plus Graphics 640',
#   'macOS',
#   '1.37kg',
#   2175.25],
#  [2,
#   'Apple',
#   'Macbook Air',
#   'Ultrabook',
#   13.3,
#   '1440x900',
#   'Intel Core i5 1.8GHz',
#   '8GB',
#   '128GB Flash Storage',
#   'Intel HD Graphics 6000',
#   'macOS',
#   '1.34kg',
#   1459.61]]

# %%
# Task 2
def largest_screen(table):
    """
    Input: A table containing all the data that is available in the given data file (table) 
    Output: Details of laptop/s with the largest screen displayed on the screen.

    For example:
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> largest_screen(laptops_data)
    Largest Screen Size: 18.4
    [156, 'MSI', 'GE73VR 7RE', 'Gaming', 18.4, 'Full HD 1920x1080', 'Intel Core i7 7700HQ 2.8GHz', '16GB', '256GB SSD +  1TB HDD', 'Nvidia GeForce GTX 1060', 'Windows 10', '2.8kg', 3068.79]
    [181, 'MSI', 'GT80S 6QF-074US', 'Gaming', 18.4, 'Full HD 1920x1080', 'Intel Core i7 6920HQ 2.9GHz', '32GB', '512GB SSD +  1TB HDD', 'Nvidia GTX 980 SLI', 'Windows 10', '4.4kg', 4544.74]
    """
    pass
    maximum_size = 0
    for i in range(len(lst)):
        if lst[i][4] > maximum_size:
            maximum_size = lst[i][4]
    print( "Largest Screen Size: " + str(maximum_size))
    for i in range(len(lst)):
        if lst[i][4] == maximum_size:
            print(lst[i])
    return None

largest_screen(lst)
# Out:
# Largest Screen Size: 18.4
# [156, 'MSI', 'GE73VR 7RE', 'Gaming', 18.4, 'Full HD 1920x1080', 'Intel Core i7 7700HQ 2.8GHz', '16GB', '256GB SSD +  1TB HDD', 'Nvidia GeForce GTX 1060', 'Windows 10', '2.8kg', 3068.79]
# [181, 'MSI', 'GT80S 6QF-074US', 'Gaming', 18.4, 'Full HD 1920x1080', 'Intel Core i7 6920HQ 2.9GHz', '32GB', '512GB SSD +  1TB HDD', 'Nvidia GTX 980 SLI', 'Windows 10', '4.4kg', 4544.74]

# %%
#Task3
company = "Apple"
laptop_number = 0
for i in range(len(lst)):
    if lst[i][1] == company:
        laptop_number += 1
print(laptop_number)
# Out:
# 21

# %%
# Task 4
def in_range(table,row,lowerbound,upperbound):
    """
    Input: A table containing all the data that is available in the given data file, a minimum price and a maximum  price.
    Output: True if the price of the laptop is within the range, and False otherwise.

    For example: 
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> in_range(laptops_data,2,800,1200)
    True
    >>> in_range(laptops_data,2,1000,1200)
    False
    >>> in_range(laptops_data,267,800,1200)
    False
    >>> in_range(laptops_data,2,800,0)
    False
    """
    pass
    if row >= 0 and row < len(table):
        if table[row][12] >= lowerbound and table[row][12] <= upperbound:
            return True
        else:
            return False
    else:
        return False
    
in_range(lst,2,800,200)
# Out:
# False

# %%
#Task 5
def unique_field_values(table, field):
    """
    Input: A table containing all the data that is available in the given data file and a field name (column heading). Only acceptable fields are company and type name.
    Output: The list of all the laptop companies (unique) without repetition.

    For example: 
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> unique_field_values(laptops_data,'company')
    ['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer', 'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG']
    >>> unique_field_values(laptops_data,'type name')
    ['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible', 'Workstation']
    >>> print(unique_field_values(laptops_data,'abc'))
    Invalid field
    """
    pass
    field = field.lower()
    if field == "company":
        companies = []
        for row in table:
            if row[1] not in companies:
                companies.append(row[1])
        return companies
    elif field == "type name":
        type_names = []
        for row in table:
            if row[3] not in type_names:
                type_names.append(row[3])
        return type_names
    else:
        print("Invalid field")
        return None
    
print(unique_field_values(lst, "type name"))
# Out:
# ['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible', 'Workstation']

# %%
# Task 6
def preferred_laptops(table):
    i = 0
    while i in range(len(table)):
        number_of_ram = table[i][7].replace("GB", "")
        number_of_ram = float(number_of_ram)
        number_of_weight = table[i][11].replace("kg", "")
        number_of_weight = float(number_of_weight)
        if number_of_ram >= 4 and number_of_weight <= 2 and float(table[i][4]) >= 14:
            table[i].append("preferred")
        else:
            table[i].append("not")
        i += 1
preferred_laptops(lst)
print(lst[1])
# Out:
# [2, 'Apple', 'Macbook Air', 'Ultrabook', 13.3, '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', 1459.61, 'not']

# %%
def record_preferred(table, output_filename='preferred_laptops.txt'):
    """
    Input: A table containing all the data that is available in the given data file with the preferred column  appended.
    Output: The given file updated with the details of the preferred laptops.

    For example: 
    >>> laptops_data = read_data('laptop_dataset.txt')
    >>> preferred_laptops(laptops_data)
    >>> record_preferred(laptops_data, 'preferred_laptops.txt')
    """
    pass
    file = open(output_filename, 'w')
    file.write("Preferred Laptop Details: \n")
    file.write("laptop id,company,product,type name,screen size,screen resolution,CPU,RAM,memory,GPU,Operating System,weight,price\n")
    for i in range(len(table)):
        if table[i][13] == 'preferred':
            file.write(",".join(str(table[i])))
        file.write('\n')
record_preferred(lst)

# %%
def read_data(filename):
    table = []
    with open(filename, 'r', encoding='latin-1') as file:
        headers = file.readline().strip().split(',')  # Read the first line for headers
        for line in file:
            values = line.strip().split(',')
            row = {}
            for i, value in enumerate(values):
                if is_float(value):  # Convert to float if possible
                    row[headers[i]] = float(value)
                else:
                    row[headers[i]] = value
            table.append(row)
    return table
print(read_data('laptop_dataset.txt'))
# Out:
# [{'laptop id': '1', 'company': 'Apple', 'product': 'MacBook Pro', 'type name': 'Ultrabook', 'screen size': 13.3, 'screen resolution': 'IPS Panel Retina Display 2560x1600', 'CPU': 'Intel Core i5 2.3GHz', 'RAM': '8GB', 'memory': '128GB SSD', 'GPU': 'Intel Iris Plus Graphics 640', 'Operating System': 'macOS', 'weight': '1.37kg', 'price': 2175.25}, {'laptop id': '2', 'company': 'Apple', 'product': 'Macbook Air', 'type name': 'Ultrabook', 'screen size': 13.3, 'screen resolution': '1440x900', 'CPU': 'Intel Core i5 1.8GHz', 'RAM': '8GB', 'memory': '128GB Flash Storage', 'GPU': 'Intel HD Graphics 6000', 'Operating System': 'macOS', 'weight': '1.34kg', 'price': 1459.61}, {'laptop id': '3', 'company': 'HP', 'product': '250 G6', 'type name': 'Notebook', 'screen size': 15.6, 'screen resolution': 'Full HD 1920x1080', 'CPU': 'Intel Core i5 7200U 2.5GHz', 'RAM': '8GB', 'memory': '256GB SSD', 'GPU': 'Intel HD Graphics 620', 'Operating System': 'No OS', 'weight': '1.86kg', 'price': 933.63}, {'laptop id': '4', 'company': 'Apple', 'product': 'MacBook Pro', 'type name': 'Ultrabook', 'screen size': 15.4, 'screen resolution': 'IPS Panel Retina Display 2880x1800', 'CPU': 'Intel Core i7 2.7GHz', 'RAM': '16GB', 'memory': '512GB SSD', 'GPU': 'AMD Radeon Pro 455', 'Operating System': 'macOS', 'weight': '1.83kg', 'price': 4120.06}, {'laptop id': '5', 'company': 'Apple', 'product': 'MacBook Pro', 'type name': 'Ultrabook', 'screen size': 13.3, 'screen resolution': 'IPS Panel Retina Display 2560x1600', 'CPU': 'Intel Core i5 3.1GHz', 'RAM': '8GB', 'memory': '256GB SSD', 'GPU': 'Intel Iris Plus Graphics 650', 'Operating System': 'macOS', 'weight': '1.37kg', 'price': 2928.51}, {'laptop id': '6', 'company': 'Acer', 'product': 'Aspire 3', 'type name': 'Notebook', 'screen size': 15.6, 'screen resolution': '1366x768', 'CPU': 'AMD A9-Series 9420 3GHz', 'RAM': '4GB', 'memory': '500GB HDD', 'GPU': 'AMD Radeon R5', 'Operating System': 'Windows 10', 'weight': '2.1kg', 'price': 649.48}, {'laptop id': '7', 'company': 'Apple', 'product': 'MacBook Pro', 'type name': 'Ultrabook', 'screen size': 15.4, 'screen resolution': 'IPS Panel Retina Display 2880x1800', 'CPU': 'Intel Core i7 2.2GHz', 'RAM': '16GB', 'memory': '256GB Flash Storage', 'GPU': 'Intel Iris Pro Graphics', 'Operating System': 'Mac OS X', 'weight': '2.04kg', 'price': 3474.67}, {'laptop id': '8', 'company': 'Apple', 'product': 'Macbook Air', 'type name': 'Ultrabook', 'screen size': 13.3, 'screen resolution': '1440x900', 'CPU': 'Intel Core i5 1.8GHz', 'RAM': '8GB', 'memory': '256GB Flash Storage', 'GPU': 'Intel HD Graphics 6000', 'Operating System': 'macOS', 'weight': '1.34kg', 'price': 1881.38}, {'laptop id': '9', 'company': 'Asus', 'product': 'ZenBook UX430UN', 'type name': 'Ultrabook', 'screen size': '14', 'screen resolution': 'Full HD 1920x1080', 'CPU': 'Intel Core i7 8550U 1.8GHz', 'RAM': '16GB', 'memory': '512GB SSD', 'GPU': 'Nvidia GeForce MX150', 'Operating System': 'Windows 10', 'weight': '1.3kg', 'price': 2427.43}, {'laptop id': '10', 'company': 'Acer', 'product': 'Swift 3', 'type name': 'Ultrabook', 'screen size': '14', 'screen resolution': 'IPS Panel Full HD 1920x1080', 'CPU': 'Intel Core i5 8250U 1.6GHz', 'RAM': '8GB', 'memory': '256GB SSD', 'GPU': 'Intel UHD Graphics 620', 'Operating System': 'Windows 10', 'weight': '1.6kg', 'price': 1250.25}, {'laptop id': '11', 'company': 'HP', 'product': '250 G6', 'type name': 'Notebook', 'screen size': 15.6, 'screen resolution': '1366x768', 'CPU': 'Intel Core i5 7200U 2.5GHz', 'RAM': '4GB', 'memory': '500GB HDD', 'GPU': 'Intel HD Graphics 620', 'Operating System': 'No OS', 'weight': '1.86kg', 'price': 639.58}, {'laptop id': '12', 'company': 'HP', 'product': '250 G6', 'type name': 'Notebook', 'screen size': 15.6, 'screen resolution': 'Full HD 1920x1080', 'CPU': 'Intel Core i3 6006U 2GHz', 'RAM': '4GB', 'memory': '500GB HDD', 'GPU': 'Intel HD Graphics 520', 'Operating System': 'No OS', 'weight': '1.86kg', 'price': 560.16}, {'laptop id': '13', 'company': 'Apple', 'p ...
